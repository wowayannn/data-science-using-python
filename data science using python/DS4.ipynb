# %%
f = open('day_4.txt',mode = 'w')
f.write('This is day 4 of ds training!!')
f.close()
print('done')
# Out:
# done

# %%
pip install googlesearch-python
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Collecting googlesearch-python
#   Downloading googlesearch_python-1.3.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: beautifulsoup4>=4.9 in c:\programdata\anaconda3\lib\site-packages (from googlesearch-python) (4.12.3)
# Requirement already satisfied: requests>=2.20 in c:\programdata\anaconda3\lib\site-packages (from googlesearch-python) (2.32.3)
# Requirement already satisfied: soupsieve>1.2 in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4>=4.9->googlesearch-python) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.20->googlesearch-python) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.20->googlesearch-python) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.20->googlesearch-python) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests>=2.20->googlesearch-python) (2025.4.26)
# Downloading googlesearch_python-1.3.0-py3-none-any.whl (5.6 kB)
# Installing collected packages: googlesearch-python
# Successfully installed googlesearch-python-1.3.0

# %%
from googlesearch import search

title = 'AI ML Complete tutorial pdf'

data = search(title,num_results=10)
all_data = []
for i in data:
    all_data.append(i+'\n')
file = open(f'{title}.txt',mode = 'w')
file.writelines(all_data)
file.close()
print('done')
# Out:
# done

# %%
from googlesearch import search

title = 'java tutorial pdf'

data = search(title,num_results=10)
all_data = []
for i in data:
    all_data.append(i+'\n')
file = open(f'{title}.txt',mode = 'x')  #mode x =it nonly creates new file
file.writelines(all_data)
file.close()
print('done')
# Out:
# done

# %%
from googlesearch import search

title = 'chat GPT trending news and investments'

data = search(title,num_results=5)
all_data = []
for i in data:
    all_data.append(i+'\n')
file = open(f'{title}.txt',mode = 'a')
file.write('============================================\n')
file.writelines(all_data)
file.close()
print('done')
# Out:
# done

# %%
f = open('new.txt','w')
print(f.read())
f.close()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[13], line 2
#       1 f = open('new.txt','w')
# ----> 2 print(f.read())
#       3 f.close()
#
# UnsupportedOperation: not readable

# %%
f = open('day_4.txt','r')
f.write('this is just a line!!')
f.close()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[14], line 2
#       1 f = open('day_4.txt','r')
# ----> 2 f.write('this is just a line!!')
#       3 f.close()
#
# UnsupportedOperation: not writable

# %%
f = open('day_4.txt','r+')
print(f.read())
f.write('\n this is again a new line!!')
f.close()
# Out:
# This is day 4 of ds training!!this is a new line!!
# this is again a new line!!
#  this is again a new line!!
#  this is again a new line!!

# %%
f = open('day_4.txt','w+')
f.write('this is again a new line!!')
f.seek(0)  #cursor set to zero(0)
print(f.read())
f.close()
# Out:
# this is again a new line!!

# %%
f1 = open('day_4.txt','r')
all_data = f1.read()

f2 = open('day_4_copy.txt','w')
f2.write(all_data)

f1.close()
f2.close()
print('done')
# Out:
# done

# %%
url = '''https://github.com/wowayannn/data-science-using-python/tree/main'''
import qrcode 
img = qrcode.make(url)
img.save('gitqr.png')

# %%
# BINARY FILE HANDLING

# %%
path = r'''C:\Users\ayan1\Downloads\cat2.jpg'''
file = open(path,mode = 'rb')  # rb: reads binary
data = file.read()
print('done')
# Out:
# done

# %%
type(data)
# Out:
# bytes

# %%
url = '''https://tse2.mm.bing.net/th/id/OIP.nr7EQzGpq6_Avdt3HhxVuQHaEK?pid=Api&P=0&h=180'''
import requests as r
image_data=r.get(url).content
type(image_data)
# Out:
# bytes

# %%
f= open('download_image.jpg','wb')
f.write(image_data)
f.close
from IPython import display
display.Image('download_image.jpg')

# %%
url = '''https://picsum.photos/1500/1080'''
import requests as r
n= 10
for i in range(n):
    img_data = r.get(url).content
    f = open(f'image_{i}.jpg','wb')
    f.write(img_data)
    f.close()
    from IPython import display as d
    display(d.Image(f'image_{i}.jpg',width=200, height=200))

# %%
 url_path = '''https://www.python.org/ftp/python/3.13.5/python-3.13.5-amd64.exe'''

#context manager
import requests as r
with open (r'C:\Users\ayan1\OneDrive\Desktop\New folder\ayan.exe','wb') as file:
    file.write(r.get(url_path).content)
print('done')
# Out:
# done
